# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pytesseract
plt.style.use('dark_background')

# %%
img_ori = cv2.imread(r'~~~~~~~~~~~~~~~~~~~/Day (365).png')

height, width, channel = img_ori.shape

plt.figure(figsize=(12, 10))
plt.imshow(img_ori)

# %%
import cv2
import numpy as np

gray = cv2.cvtColor(img_ori, cv2.COLOR_BGR2GRAY)

plt.figure(figsize=(12, 10))
plt.imshow(img2, cmap='gray')

print (img2.shape)
print (gray.shape)
# Out:
# (54, 126, 3)
# (54, 126)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

image = gray
image_enhanced = cv2.equalizeHist(image) # 이미지 대비를 향상시킵니다.
plt.imshow(image_enhanced, cmap="gray"), plt.axis("off") # 이미지 출력
plt.show()

print (gray.shape)
print (image.shape)
# Out:
# (44, 151)
# (44, 151)

# %%
img2 = np.zeros_like(img_ori)
img2[:,:,0] = image_enhanced
img2[:,:,1] = image_enhanced
img2[:,:,2] = image_enhanced

plt.imshow(img2)

# %%
img_f = cv2.flip(img2, 1)
plt.imshow(img_f)
